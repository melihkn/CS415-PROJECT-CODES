# %% [markdown]
# # Training on Google Colab
#
# Use this notebook to run your `train.py` script in Google Colab.
#
# ### Steps:
# 1. Upload your entire project folder (`CS415-PROJECT-CODES`) to your Google Drive.
# 2. Open this notebook in Google Colab.
# 3. Run the cells below.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# TODO: Update this path to match where you uploaded the project in your Google Drive
# For example, if you put it in the root of your drive, it might be:
project_path = '/content/drive/MyDrive/CS415-PROJECT-CODES'

import os
try:
    os.chdir(project_path)
    print(f"Successfully changed directory to: {os.getcwd()}")
except FileNotFoundError:
    print(f"Error: The path '{project_path}' does not exist. Please check your Google Drive structure.")

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Run the training script
# You can pass arguments like --model, --epochs, etc.
# !python train.py --model hfanet --epochs 10 --data_dir ./data
